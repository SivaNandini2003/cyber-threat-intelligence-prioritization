# %%
import json
import requests
#1
# Load dataset from MITRE
url = "https://raw.githubusercontent.com/mitre/cti/master/enterprise-attack/enterprise-attack.json"
response = requests.get(url)
data = response.json()

# Extract only attack-pattern objects
techniques = [
    obj for obj in data.get("objects", [])
    if obj.get("type") == "attack-pattern"
]

print("Total attack techniques extracted:", len(techniques))

#2
def threat_score(tech):
    score = 5  # Base score

    name = tech.get("name", "").lower()
    description = tech.get("description", "").lower()

    # -------- Name-Based Intelligence --------
    if "credential" in name:
        score += 3
    if "execution" in name:
        score += 2
    if "privilege" in name:
        score += 3
    if "persistence" in name:
        score += 2
    if "lateral" in name:
        score += 2

    # -------- Description-Based Intelligence --------
    if "administrator" in description:
        score += 2
    if "remote" in description:
        score += 2
    if "bypass" in description:
        score += 2
    if "stealth" in description:
        score += 1

    return score

#3
scored_techniques = []

for tech in techniques:
    score = threat_score(tech)
    scored_techniques.append((tech.get("name", "Unknown"), score))

print("Scoring complete.")

#4
# Sort from highest to lowest score
scored_techniques.sort(key=lambda x: x[1], reverse=True)

print("Top 10 Highest-Risk Techniques:\n")

for name, score in scored_techniques[:10]:
    print(f"{name} — Score: {score}")

#5
print("\nCritical Threats (Score >= 8.9):\n")

for name, score in scored_techniques:
    if score >= 8.9:
        print(f"{name} — Score: {score}")
# Out:
# Total attack techniques extracted: 835
# Scoring complete.
# Top 10 Highest-Risk Techniques:
#
# Additional Cloud Credentials — Score: 12
# Bypass User Account Control — Score: 11
# Distributed Component Object Model — Score: 11
# Component Object Model and Distributed COM — Score: 11
# Valid Accounts — Score: 11
# SID-History Injection — Score: 11
# Pass the Hash — Score: 11
# Access Token Manipulation — Score: 11
# Credentials from Web Browsers — Score: 10
# Credentials from Web Browsers — Score: 10
#
# Critical Threats (Score >= 8.9):
#
# Additional Cloud Credentials — Score: 12
# Bypass User Account Control — Score: 11
# Distributed Component Object Model — Score: 11
# Component Object Model and Distributed COM — Score: 11
# Valid Accounts — Score: 11
# SID-History Injection — Score: 11
# Pass the Hash — Score: 11
# Access Token Manipulation — Score: 11
# Credentials from Web Browsers — Score: 10
# Credentials from Web Browsers — Score: 10
# Pass the Ticket — Score: 10
# Credentials In Files — Score: 10
# Forge Web Credentials — Score: 10
# Credentials in Files — Score: 10
# Credentials — Score: 10
# Pass the Hash — Score: 10
# Extra Window Memory Injection — Score: 9
# Scheduled Task — Score: 9
# Boot or Logon Initialization Scripts — Score: 9
# PubPrn — Score: 9
# Steal Web Session Cookie — Score: 9
# SID-History Injection — Score: 9
# Application Access Token — Score: 9
# Spearphishing Link — Score: 9
# Application Deployment Software — Score: 9
# Indirect Command Execution — Score: 9
# Additional Local or Domain Groups — Score: 9
# Application Shimming — Score: 9
# System Binary Proxy Execution — Score: 9
# DLL Search Order Hijacking — Score: 9
# CMSTP — Score: 9
# SMB/Windows Admin Shares — Score: 9
# Extra Window Memory Injection — Score: 9
# Disable or Modify System Firewall — Score: 9
# Browser Session Hijacking — Score: 9
# Hybrid Identity — Score: 9
# Rogue Domain Controller — Score: 9
# Modify Registry — Score: 9
# Default Accounts — Score: 9
# At (Linux) — Score: 9
# Image File Execution Options Injection — Score: 9
# Domain Account — Score: 9
# Poisoned Pipeline Execution — Score: 9
# Application Shimming — Score: 9
# CMSTP — Score: 9
# Build Image on Host — Score: 9
# Verclsid — Score: 9
# Network Device CLI — Score: 9
# Steal Application Access Token — Score: 9
# User Execution — Score: 9
# Software Deployment Tools — Score: 9
# PowerShell — Score: 9
# Brute Force — Score: 9
# Remote Access Hardware — Score: 9
# Exploitation for Client Execution — Score: 9
# Lateral Tool Transfer — Score: 9
# Bypass User Account Control — Score: 9
# Hidden Window — Score: 9
# Create Cloud Instance — Score: 9
# Cloud Administration Command — Score: 9
# XSL Script Processing — Score: 9
# SNMP (MIB Dump) — Score: 9
# Application Access Token — Score: 9
# Service Execution — Score: 9
# Cloud Accounts — Score: 9
# DCSync — Score: 9
# At — Score: 9
# PowerShell — Score: 9
# Modify Authentication Process — Score: 9
# System Script Proxy Execution — Score: 9
# Wi-Fi Networks — Score: 9
# Trusted Developer Utilities Proxy Execution — Score: 9
# Windows Admin Shares — Score: 9
